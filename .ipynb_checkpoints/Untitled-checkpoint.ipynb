# %%
API_ACCESS_TOKEN='5ed71e2454083f5b7bb83d3bcc59caec1538e6cd9b9e1c4b220fdf7b2709cfd9'

headers = {
    'Authorization': f'Bearer {API_ACCESS_TOKEN}',
    'Content-Type': 'application/json'
}

response = requests.get(url, headers=headers)

# Pretty-print the JSON response
if response.status_code == 200:
    data = response.json()
    print(json.dumps(data, indent=2))
else:
    print(f"Error: {response.status_code} - {response.text}")


Tento kod v poradku odeslal buy objednavku na 2 akcie do RST:

order_size = 2
signal = 1
ticker = "SHEL.L.XLON"

if signal != 0:  # If there's a buy or sell signal
    side = "buy" if signal == 1 else "sell"

    url = 'https://api.stockstrader.com/api/v1/accounts/92150653/orders'

    order_data = {
        "ticker": ticker,
        "side": side,
        "type": "market",
        "volume": order_size
    }

    headers = {
        'Authorization': f'Bearer {API_ACCESS_TOKEN}',
        'Content-Type': 'application/json'
    }

    response = requests.post(url, headers=headers, data=order_data)

    print(response.status_code, response.text)

url = 'https://api.stockstrader.com/api/v1/accounts/92150653/instruments/SHEL.L.XLON/quote'

headers = {
    'Authorization': f'Bearer {API_ACCESS_TOKEN}',
    'Content-Type': 'application/json'
}

response = requests.get(url, headers=headers)

# Pretty-print the JSON response
if response.status_code == 200:
    data = response.json()
    print(json.dumps(data, indent=2))
else:
    print(f"Error: {response.status_code} - {response.text}")




order_size = 2
signal = 1
ticker = "SHEL.L.XLON"

if signal != 0:  # If there's a buy or sell signal
    side = "buy" if signal == 1 else "sell"

    url = 'https://api.stockstrader.com/api/v1/accounts/92150653/orders'

    order_data = {
        "ticker": ticker,
        "side": side,
        "type": "market",
        "volume": order_size
    }

    headers = {
        'Authorization': f'Bearer {API_ACCESS_TOKEN}',
        'Content-Type': 'application/json'
    }

    response = requests.post(url, headers=headers, data=order_data)

    print(response.status_code, response.text)
# Out:
#   Cell In[3], line 18
#     Tento kod v poradku odeslal buy objednavku na 2 akcie do RST:
#           ^
# SyntaxError: invalid syntax
